# %%
from src.utils.consts import MODELS_PATH
from src.visualization.metrics_visualization import plot_metric_comparison
from src.visualization.model_visualization import plot_combined_analysis, plot_model_class_comparison, plot_combined_model_performance

# %%
# Models Comparision
output_path = "DenseNetV7"
model_names = ['DenseNetV4_1', 'DenseNetV5_2', 'DenseNetV7_1', 'DenseNetV7_2']

# %%
plot_metric_comparison(MODELS_PATH, model_names, 'f1_score', output_path)
# Out:
# Combined training and validation comparison saved to: /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/models/DenseNetV7/model_comparison_f1_score.png

# %%
plot_combined_model_performance(MODELS_PATH, model_names, [], output_path)
# Out:
# Combined model performance visualization saved to: /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/models/DenseNetV7/combined_model_performance.png

# %%
plot_model_class_comparison(MODELS_PATH, model_names, 'f1_score', [], output_path)
# Out:
# Class comparison visualization saved to: /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/models/DenseNetV7/model_class_comparison_f1_score.png

# %%
plot_combined_analysis(MODELS_PATH, 'DenseNetV5_3')
