# %%
from src.utils.consts import MODELS_PATH
from src.visualization.metrics_visualization import plot_metric_comparison
from src.visualization.model_visualization import plot_combined_analysis, plot_model_class_comparison

# %%
# Models Comparision
output_path = "DenseNet5"
model_names = ['DenseNetV4_1', 'DenseNetV5_1', 'DenseNetV5_2']

# %%
plot_metric_comparison(MODELS_PATH, model_names, 'f1_score', output_path)
# Out:
# Combined training and validation comparison saved to: /home/piotr/Pulpit/codebook/studies/bachelor-thesis/models/DenseNet5/model_comparison_f1_score.png

# %%
plot_model_class_comparison(MODELS_PATH, model_names, 'f1_score', [], output_path)
# Out:
# Class comparison visualization saved to: /home/piotr/Pulpit/codebook/studies/bachelor-thesis/models/DenseNet5/model_class_comparison_f1_score.png

# %%
plot_combined_analysis(MODELS_PATH, 'DenseNetV5_1')

# %%
plot_combined_analysis(MODELS_PATH, 'DenseNetV5_2')

# %%
plot_combined_analysis(MODELS_PATH, 'DenseNetV4_1')
