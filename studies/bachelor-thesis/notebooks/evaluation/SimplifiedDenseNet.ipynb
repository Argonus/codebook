# %%
from src.utils.consts import MODELS_PATH
from src.visualization.metrics_visualization import plot_metric_comparison
from src.visualization.model_visualization import plot_combined_analysis

# %%
# Models Comparision
model_names = ['SimplifiedDenseNetV1_1', 'SimplifiedDenseNetV1_2', 'DenseNetV1_1']
plot_metric_comparison(MODELS_PATH, model_names, 'val_metrics.csv', 'val_f1_score')

# %%
plot_metric_comparison(MODELS_PATH, model_names, 'train_metrics.csv', 'f1_score')

# %%
plot_combined_analysis(MODELS_PATH, 'SimplifiedDenseNetV1_1')

# %%
plot_combined_analysis(MODELS_PATH, 'SimplifiedDenseNetV1_2')

# %%
plot_combined_analysis(MODELS_PATH, 'SimplifiedDenseNetV1_3')

# %%
plot_combined_analysis(MODELS_PATH, 'DenseNetV1_1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plot_combined_analysis(MODELS_PATH, 'DenseNetV1_1')
#
# File ~/Pulpit/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:72, in plot_combined_analysis(metrics_path, model_name)
#      70 validation_df = _get_csv(metrics_path, model_name, 'val_metrics.csv')
#      71 validation_df["loss"] = validation_df["val_loss"]
# ---> 72 model_metrics_df = _get_csv(metrics_path, model_name, 'model_metrics.csv')
#      74 fig = plt.figure(figsize=(25, 20))
#      75 plt.rcParams.update({'font.size': 14})
#
# File ~/Pulpit/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:8, in _get_csv(metrics_path, model_name, file_name)
#       6 """Read a CSV file and return a DataFrame"""
#       7 file_path = f"{metrics_path}/{model_name}/{file_name}"
# ...
