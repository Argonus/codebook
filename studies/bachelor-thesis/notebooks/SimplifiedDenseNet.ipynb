# %%
from src.utils.consts import MODELS_PATH
from src.visualization.metrics_visualization import plot_metric_comparison
from src.visualization.model_visualization import plot_combined_analysis

# %%
# Models Comparision
model_names = ['Simplified_DenseNet_v1', 'Simplified_DenseNet_v2', 'Simplified_DenseNet_v3', 'Simplified_DenseNet_v4', 'Simplified_DenseNet_v5']
plot_metric_comparison(MODELS_PATH, model_names, 'val_metrics.csv', 'val_f1_score')

# %%
# Models Comparision
model_names = ['Simplified_DenseNet_v1', 'Simplified_DenseNet_v2', 'Simplified_DenseNet_v3', 'Simplified_DenseNet_v4', 'Simplified_DenseNet_v5']
plot_metric_comparison(MODELS_PATH, model_names, 'train_metrics.csv', 'f1_score')

# %%
# Model Analysis
plot_combined_analysis(MODELS_PATH, 'Simplified_DenseNet_v1')
# Out:
# /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_data['total_confidence'] = latest_data['high_confidence_ratio'] + latest_data['medium_confidence_ratio']
# /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:88: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df['class_name'], rotation=45, ha='right')
# ...

# %%
# Model Analysis
plot_combined_analysis(MODELS_PATH, 'Simplified_DenseNet_v2')
# Out:
# /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_data['total_confidence'] = latest_data['high_confidence_ratio'] + latest_data['medium_confidence_ratio']
# /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:88: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df['class_name'], rotation=45, ha='right')
# ...

# %%
# Model Analysis
plot_combined_analysis(MODELS_PATH, 'Simplified_DenseNet_v3')
# Out:
# /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_data['total_confidence'] = latest_data['high_confidence_ratio'] + latest_data['medium_confidence_ratio']
# /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:88: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df['class_name'], rotation=45, ha='right')
# ...

# %%
# Model Analysis
plot_combined_analysis(MODELS_PATH, 'Simplified_DenseNet_v4')
# Out:
# /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_data['total_confidence'] = latest_data['high_confidence_ratio'] + latest_data['medium_confidence_ratio']
# /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:88: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df['class_name'], rotation=45, ha='right')
# ...

# %%
plot_combined_analysis(MODELS_PATH, 'Simplified_DenseNet_v5')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plot_combined_analysis(MODELS_PATH, 'Simplified_DenseNet_v5')
#
# File ~/Projects/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:141, in plot_combined_analysis(metrics_path, model_name)
#     138 validation_df["loss"] = validation_df["val_loss"]
#     140 loss_analysis_df = _get_csv(metrics_path, model_name, 'loss_analysis_metrics.csv')
# --> 141 model_metrics_df = _get_csv(metrics_path, model_name, 'model_metrics.csv')
#     143 fig = plt.figure(figsize=(30, 30))
#     144 plt.rcParams.update({'font.size': 18})
#
# File ~/Projects/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:8, in _get_csv(metrics_path, model_name, file_name)
#       6 """Read a CSV file and return a DataFrame"""
#       7 file_path = f"{metrics_path}/{model_name}/{file_name}"
# ...
