# %%
from src.utils.consts import TF_RECORD_DATASET, TF_BUFFER_SIZE
from src.model.tensorflow_utils import load_dataset, show_sample_record, show_augmented_sample

main_path  = f"{TF_RECORD_DATASET}/chest_xray_data.tfrecord"
train_path = f"{TF_RECORD_DATASET}/train.tfrecord"
test_path  = f"{TF_RECORD_DATASET}/test.tfrecord"
val_path   = f"{TF_RECORD_DATASET}/val.tfrecord"

main_ds = load_dataset(main_path, TF_BUFFER_SIZE)
train_ds = load_dataset(train_path, TF_BUFFER_SIZE)
test_ds = load_dataset(test_path, TF_BUFFER_SIZE)
val_ds = load_dataset(val_path, TF_BUFFER_SIZE)

show_augmented_sample(train_ds)
# Out:
# 2025-03-16 22:20:35.455722: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2025-03-16 22:20:35.455866: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 48.00 GB
# 2025-03-16 22:20:35.455871: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 18.00 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742160035.456289 11820326 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1742160035.456342 11820326 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ...
