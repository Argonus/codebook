# %%
from src.utils.consts import TF_RECORD_DATASET, TF_BUFFER_SIZE
from src.model.tensorflow_utils import load_dataset, apply_augmentation_to_dataset, show_augmented_sample

train_path = f"{TF_RECORD_DATASET}/train.tfrecord"

train_ds = load_dataset(train_path, TF_BUFFER_SIZE)
show_augmented_sample(train_ds)
# Out:
# 2025-04-02 15:23:42.685651: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2025-04-02 15:23:42.685686: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 48.00 GB
# 2025-04-02 15:23:42.685689: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 18.00 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743600222.685730 33809970 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1743600222.685768 33809970 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2025-04-02 15:23:42.955315: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:376] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 262144
# 2025-04-02 15:23:42.981712: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
