# %%
from src.utils.consts import TF_RECORD_DATASET, TF_BUFFER_SIZE
from src.model.tensorflow_utils import load_dataset, apply_augmentation_to_dataset, show_augmented_sample

train_path = f"{TF_RECORD_DATASET}/train.tfrecord"
train_ds = load_dataset(train_path, TF_BUFFER_SIZE)
show_augmented_sample(train_ds)
# Out:
# 2025-06-22 12:11:45.641098: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2025-06-22 12:11:45.641119: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 48.00 GB
# 2025-06-22 12:11:45.641122: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 18.00 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750587105.641141 7646946 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1750587105.641163 7646946 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2025-06-22 12:11:45.712365: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:376] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 8388608
# 2025-06-22 12:11:45.815011: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0665298..2.0984504].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0665298..1.6415647].

# %%
from src.model.tensorflow_utils import calculate_class_weights, show_class_weights

train_ds = load_dataset(f"{TF_RECORD_DATASET}/train.tfrecord", TF_BUFFER_SIZE)
val_ds   = load_dataset(f"{TF_RECORD_DATASET}/val.tfrecord", TF_BUFFER_SIZE)
test_ds   = load_dataset(f"{TF_RECORD_DATASET}/test.tfrecord", TF_BUFFER_SIZE)

train_weights = calculate_class_weights(train_ds, 15)
val_weights   = calculate_class_weights(val_ds, 15)
test_weights  = calculate_class_weights(test_ds, 15)
# Out:
# 2025-06-22 12:13:00.057610: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-06-22 12:13:03.659170: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# 2025-06-22 12:13:16.216070: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-06-22 12:13:20.282537: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
