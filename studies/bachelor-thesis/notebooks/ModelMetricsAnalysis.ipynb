# %%
from src.utils.consts import MODELS_PATH
from src.visualization.metrics_visualization import plot_metrics, plot_metric_comparison
from src.visualization.model_visualization import plot_model_metrics
from src.visualization.loss_analysis_visualization import plot_loss_analysis

# %%
# Model Analysis
model_name = 'Simplified_DensNet_v1'
metrics_path = f"{MODELS_PATH}/{model_name}"

# %%
plot_metrics(metrics_path, "train_metrics.csv")

# %%
plot_metrics(metrics_path, "val_metrics.csv", 'val_')

# %%
plot_model_metrics(metrics_path, 'model_metrics.csv')
# Out:
# /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/src/visualization/model_visualization.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(df['class_name'], rotation=45, ha='right')

# %%
plot_loss_analysis(metrics_path, 'loss_analysis_metrics.csv')
# Out:
# /Users/piotr.r/Projects/codebook/studies/bachelor-thesis/src/visualization/loss_analysis_visualization.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_data['total_confidence'] = latest_data['high_confidence_ratio'] + latest_data['medium_confidence_ratio']

# %%
model_names = ['Simplified_DensNet_v1', 'Simplified_DensNet_v2']
plot_metric_comparison(MODELS_PATH, model_names, 'val_metrics.csv', 'val_f1_score')
